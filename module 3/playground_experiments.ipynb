# %% [markdown]
# # Run Experiments in Playground

# %% [markdown]
# ### Setup

# %%
# Or you can use a .env file
from dotenv import load_dotenv
load_dotenv( override=True)
# Out:
# True

# %% [markdown]
# ### Create a Dataset

# %% [markdown]
# Let's create a toy example dataset to run experiments over for a prompt

# %%
from langsmith import Client

example_inputs = [
("What color is the sky?", "The sky is blue"),
("What color is grass?", "Grass is green"),
("What color is dirt?", "Dirt is brown"),
]

client = Client()
dataset_name = "Sample Questions"

dataset = client.create_dataset(
  dataset_name=dataset_name, description="Sample questions about color",
)

inputs = [{"question": input_prompt} for input_prompt, _ in example_inputs]
outputs = [{"output": output_answer} for _, output_answer in example_inputs]

client.create_examples(
  inputs=inputs,
  outputs=outputs,
  dataset_id=dataset.id,
)
# Out:
# {'example_ids': ['572e8e49-6cf4-4b48-9b19-9da1cda2aec4',
#   'f24e4301-2228-43c2-a265-a9dd5c997e22',
#   '1e9cd0b9-b439-441a-a6dd-d38d4f75256a'],
#  'count': 3}

# %%
example_inputs = [
("which sport is played by a bat and ball", "cricket is played with a bat and ball"),
("how many players are there in one team", "eleven players are there in one team"),
("how often the world cup is conducted", "world cup is conducted after every four years"),
]

client = Client()
dataset_name = "Cricket questions"

dataset = client.create_dataset(
  dataset_name=dataset_name, description="Random questions on cricket",
)

inputs = [{"question": input_prompt} for input_prompt, _ in example_inputs]
outputs = [{"output": output_answer} for _, output_answer in example_inputs]

client.create_examples(
  inputs=inputs,
  outputs=outputs,
  dataset_id=dataset.id,
)
# Out:
# {'example_ids': ['9147b9ea-176b-4c82-9bc6-2789fefb4050',
#   '2219ae30-f41d-42c9-9f3a-92fa5f0cdab0',
#   'db529ac6-df1a-46b5-b0a0-13f225c61aa4'],
#  'count': 3}

# %% [markdown]
# ![image.png](attachment:7a9e71c8-a136-4581-86b6-f117595a44ca.png)

# %% [markdown]
# ![Screenshot 2025-10-13 222249.png](attachment:1d337fff-a1df-4fac-aa58-45af9964a26f.png)
